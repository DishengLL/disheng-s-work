# %% [markdown]
# # import

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
matplotlib.rcParams['font.family'] = "serif"
file_path ='/Users/liu/Desktop/Pitts/Project/data/R3_1971_YE_ENCOUNTER_NOTES_2021_03_05/R3_1971_YE_DIAGNOSES_2021_03_01.csv'

# %%
DIAGNOSES = pd.read_csv(file_path,encoding = "ISO-8859-1",low_memory=False)
DIAGNOSES['DX_FROM_DATE'] = pd.to_datetime(DIAGNOSES['DX_FROM_DATE'], format='%m/%d/%Y')
DIAGNOSES['DX_TO_DATE'] = pd.to_datetime(DIAGNOSES['DX_TO_DATE'], format='%m/%d/%Y')
DIAGNOSES.head(20)
# Out:
#       STUDY_ID DIAGNOSIS_TYPE DX_CODE  \
# 0   5225357772         ICD9CM  011.90
# 1   5225567678         ICD9CM  013.00
# 2   5225563315         ICD9CM  013.20
# 3   5220332708         ICD9CM   027.0
# 4   5220165181         ICD9CM   027.0
# 5   5225172338         ICD9CM  016.50
# 6   5220427063         ICD9CM   002.0
# 7   5225658053         ICD9CM   003.0
# 8   5220138989         ICD9CM   003.0
# 9   5222875420         ICD9CM   003.1
# 10  5220177792         ICD9CM   003.1
# 11  5220138989         ICD9CM  003.21
# 12  5220138989         ICD9CM  003.21
# 13  5222170334         ICD9CM  005.89
# 14  5222707319         ICD9CM   005.9
# 15  5225604739         ICD9CM   005.9
# 16  5222195798         ICD9CM   005.9
# 17  5222770859         ICD9CM   005.9
# 18  5222174028         ICD9CM   007.1
# 19  5225034058         ICD9CM   007.4
#
#                                        DIAGNOSIS_NAME PRIMARY_DX_IND  \
# 0    Pulmonary tuberculosis, unspecified, unspecified              N
# ...

# %%
DIAGNOSES.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1826776 entries, 0 to 1826775
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   STUDY_ID        int64
#  1   DIAGNOSIS_TYPE  object
#  2   DX_CODE         object
#  3   DIAGNOSIS_NAME  object
#  4   PRIMARY_DX_IND  object
#  5   DX_FROM_DATE    datetime64[ns]
#  6   DX_TO_DATE      datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 97.6+ MB

# %%
DIAGNOSES.describe(include='all')
# Out:
# /var/folders/pp/qtk1lyns6zg8x9dlj6f5xvtm0000gn/T/ipykernel_28291/3173427475.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   DIAGNOSES.describe(include='all')
#             STUDY_ID DIAGNOSIS_TYPE  DX_CODE  \
# count   1.826776e+06        1806026  1826776
# unique           NaN              4    16794
# top              NaN        ICD10CM      I10
# freq             NaN        1658177    38051
# first            NaN            NaN      NaN
# last             NaN            NaN      NaN
# mean    5.223123e+09            NaN      NaN
# std     1.758561e+06            NaN      NaN
# min     5.220000e+09            NaN      NaN
# 25%     5.222196e+09            NaN      NaN
# 50%     5.222728e+09            NaN      NaN
# 75%     5.225112e+09            NaN      NaN
# ...

# %% [markdown]
# # PRIMARY_DX_IND

# %%
DIAGNOSES.PRIMARY_DX_IND.value_counts()*100/DIAGNOSES.PRIMARY_DX_IND.shape[0]
# Out:
# N    87.763689
# Y    12.236311
# Name: PRIMARY_DX_IND, dtype: float64

# %% [markdown]
# # DX_CODE

# %%
(DIAGNOSES.DX_CODE.isin(covid)).sum()*100/DIAGNOSES.shape[0]
# Out:
# 0.9470236088058963

# %%
covid = ['U07.1', 'Z11.52', 'Z20.822', 'J12.82']

# %%
covid_record = DIAGNOSES[DIAGNOSES.DX_CODE.isin(covid)]

# %%
covid_record
# Out:
#            STUDY_ID DIAGNOSIS_TYPE  DX_CODE DIAGNOSIS_NAME PRIMARY_DX_IND  \
# 1805092  5222332886          ICD10    U07.1       COVID-19              Y
# 1805093  5220589908          ICD10    U07.1       COVID-19              Y
# 1805094  5220055723          ICD10    U07.1       COVID-19              N
# 1805095  5225508479          ICD10    U07.1       COVID-19              N
# 1805096  5222867644          ICD10    U07.1       COVID-19              Y
# ...             ...            ...      ...            ...            ...
# 1826770  5222342265            NaN  Z20.822            NaN              N
# 1826771  5222512326            NaN  Z20.822            NaN              N
# 1826772  5222171889            NaN  Z20.822            NaN              N
# 1826773  5222589229            NaN  Z20.822            NaN              N
# 1826774  5222497492            NaN  Z20.822            NaN              N
#
#         DX_FROM_DATE DX_TO_DATE
# 1805092   2020-07-06        NaT
# ...

# %%
covid_record.to_csv('covid_record.csv', index = False)
